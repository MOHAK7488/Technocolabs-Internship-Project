# %% [markdown]
# <h1>Task 1</h1>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Task 1 Data set/cleaned_data.csv')

# %%
df
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24      2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2      85698822-43f5      90000    2          2         2   34      0      0
# 3      0737c11b-be42      50000    2          2         1   37      0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57     -1      0
# 5      ceae2946-47e4      50000    1          1         2   37      0      0
# 6      d3b8ce26-9c89     500000    1          1         2   29      0      0
# 7      d6e1911b-54d0     100000    2          2         2   23      0     -1
# 8      8421d3b3-2b54     140000    2          3         1   28      0      0
# 9      62a2fd79-cd90      20000    1          3         2   35     -2     -2
# 10     b73c34fc-91cf     200000    2          3         2   34      0      0
# ...

# %%
df.describe()
# Out:
#            LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count   26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean   167919.054905      1.603060      1.842334      1.556031     35.505213
# std    129839.453081      0.489272      0.744661      0.521463      9.227442
# min     10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%     50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%    140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%    240000.000000      2.000000      2.000000      2.000000     41.000000
# max    800000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# ...

# %%
df.corr()
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.027046  -0.232688 -0.111873
# SEX                          0.027046  1.000000   0.014336 -0.031307
# EDUCATION                   -0.232688  0.014336   1.000000 -0.137097
# MARRIAGE                    -0.111873 -0.031307  -0.137097  1.000000
# AGE                          0.149157 -0.088421   0.179035 -0.412828
# PAY_1                       -0.273396 -0.058993   0.112653  0.019759
# PAY_2                       -0.296471 -0.070828   0.129558  0.025096
# PAY_3                       -0.286613 -0.067869   0.124114  0.034308
# PAY_4                       -0.269296 -0.060820   0.118464  0.033082
# PAY_5                       -0.249555 -0.055418   0.105290  0.036830
# PAY_6                       -0.236037 -0.043668   0.088835  0.033366
# BILL_AMT1                    0.287009 -0.032336   0.016156 -0.028610
# BILL_AMT2                    0.279289 -0.029682   0.012307 -0.026009
# ...
